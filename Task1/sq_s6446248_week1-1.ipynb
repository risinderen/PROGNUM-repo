# %% [markdown]
# Answers for week 1
# Name: Redmar van Sinderen
# username: risinderen
# student number: S6446248
# Group: As 1

# %% [markdown]
# x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %% [markdown]
# pi = 22/7 # Processed on Jupyter Hub

# %% [markdown]
# M![dolphin.jpg](attachment:dolphin.jpg)

# %%
x = 1
x *=6
x *=5
x *=4
x *=3
x *=2
print(x)
# Out:
# 720

# %%
from scipy.constants import G
F=G
F*=7.342*10**22
F*=5.9722*10**24
F/=385000600**2
print (F)
# Out:
# 1.974384051807571e+20

# %%
from scipy.constants import G, pi
a=149597871000
p=365*24*60*60
m=((pi**2)*4*(a**3))/((p**2)*G)
print(m)
# Out:
# 1.991209877460257e+30

# %%
x1=10
x2=22/7
print(x1, end="")
print(x2, end="")
#it prints the numbers one after the other without a space in between
# Out:
# 103.142857142857143

# %% [markdown]
# ![Schermafbeelding%202026-02-11%20133146.png](attachment:Schermafbeelding%202026-02-11%20133146.png)

# %% [markdown]
# ![Schermafbeelding%202026-02-11%20135907.png](attachment:Schermafbeelding%202026-02-11%20135907.png)

# %% [markdown]
# Pwd shows the name of the file and the way to go into the file.
# . does nothing
# .. goes back to the file one above

# %% [markdown]
#     quickets way to go form a random directory to desktop you do cd ~/Desktop
