# %% [markdown]
# # Energy and frequency
#
# With Planck's constant $h$, we write the relation between energy and frequency as:
#
# $$E = hf$$

# %% [markdown]
# 2.1
# $$E = hc /\lambda$$

# %% [markdown]
# 2.2
# $$F=G\frac{{m_1}{m_2}}{r^2}$$

# %% [markdown]
# 2.3
# $$\sin(2x) = 2\sin(x)\cos(x) = \frac{2\tan(x)}{1+\tan^2(x)}$$

# %%
#2.4
from math import *
alpha_d = 30                  # degrees
alpha_r = radians(alpha_d)    # Now in radians
y=sin(2*alpha_r)
z=2*sin(alpha_r)*cos(alpha_r)
w=(2*tan(alpha_r))/(1+tan(alpha_r)**2)
print(y)
print(z)
print(w)
# Out:
# 0.8660254037844386
# 0.8660254037844386
# 0.8660254037844386

# %% [markdown]
# 2.5
# $$\displaystyle\sum_{k=0}^{\infty} \frac{1}{4k^2-1} = \frac{1}{2}$$
# $$\int_0^\pi \mathrm{e}^{ix}\, \mathrm{d}x = 2i $$ #ask about comma before dx
